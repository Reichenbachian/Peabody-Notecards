# %%
import pandas as pd
import os
from PIL import Image, ImageDraw
import pytesseract
import numpy as np
import sys
from tqdm import tqdm
import math

# %%
df = pd.DataFrame(columns=["Cat Number", "Site Number", "Locality", "Site", "Name", "Situation", "AccNum", "fileLocation"])

# %%
def bestLine(image, bMin,bMax, mMin, mMax, mStep=-1):
    if mStep == -1:
        mStep = (mMax-mMin)/20
    maxScore = 0
    maxB = -1
    maxM = -1
    for b in range(bMin, bMax, 3):
        for m in np.arange(mMin, mMax, mStep):
            score = 0
            momentum = 1
            for x in range(0, image.size[0]):
                y = int(m*x+b)
                if y > image.size[1] or x > image.size[0] or y < 1 or x < 1:
                    continue
                if image.getpixel((x, y)) == 0:
                    score += momentum
                    momentum += 1
                else:
                    momentum = 0
                    score -= 1
            if score > maxScore:
                maxScore = score
                maxB = b
                maxM = m
    if maxM == -1 or maxM == -1:
        print("ERROR")
        sys.exit()
    return maxB, maxM

##I"M SORRY FOR THE CODE REUSE!!!!!!

def cropLeft(bw):
    xSize=bw.size[0]
    ySize=bw.size[1]
    tol=20
    # Crop left
    for x in range(0, int(xSize/10)):
        pixSum = 0
        for y in range(0, ySize):
#             print(bw.getpixel((x, y)))
            if bw.getpixel((x, y)) == 0:
                pixSum += 1
            if pixSum > tol:
                return bw.crop((x, 0, xSize, ySize))
            
def cropRight(bw):
    xSize=bw.size[0]
    ySize=bw.size[1]
    tol=3
    # Crop Right
    for x in range(xSize-1, int(5*xSize/10), -1):
        pixSum = 0
        for y in range(0, ySize):
#             print(bw.getpixel((x, y)))
            if bw.getpixel((x, y)) == 0:
                pixSum += 1
            if pixSum > tol:
                return bw.crop((0, 0, x, ySize))
            
def cropTop(bw):
    xSize=bw.size[0]
    ySize=bw.size[1]
    tol=20
    # Crop left
    for y in range(0, int(ySize/10)):
        pixSum = 0
        for x in range(0, xSize):
            if bw.getpixel((x, y)) == 0:
                pixSum += 1
            if pixSum > tol:
                return bw.crop((0, y, xSize, ySize))
            
def cropBottom(bw):
    xSize=bw.size[0]
    ySize=bw.size[1]
    tol=20
    # Crop left
    for y in range(ySize-1, int(9*ySize/10), -1):
        pixSum = 0
        for x in range(0, xSize):
            if bw.getpixel((x, y)) == 0:
                pixSum += 1
            if pixSum > tol:
                return bw.crop((0, 0, xSize, y))
def rectifyImage(image):
    gray = image.convert('L')
    xSize=image.size[0]
    ySize=image.size[1]
    #Convert to black and white
    bw = gray.point(lambda x: 0 if x<200 else 255, '1')
    # Rotate image
    b, m = bestLine(bw, 500, 700, -.05, .05)
    deg = math.degrees(math.sin(abs(m*xSize)/xSize))
    bw = bw.rotate(-deg, expand=True)
    # Crop sides
    bw = cropLeft(bw)
    bw = cropRight(bw)
    bw = cropTop(bw)
    bw = cropBottom(bw)
    return bw
    

rectifyImage(Image.open("/Users/localhost/Desktop/Projects/Working/PeabodyNotecards/peabody_files/Accession Files/12/21_1766.pdf.png"))
# Out:
# <PIL.Image._ImageCrop image mode=1 size=1311x1117 at 0x10BCEADA0>

# %%
images = []
i = 0
configArgs = 'config="-c tessedit_char_whitelist=0123456789ABCDEFGHIJKLMNOPQRSTUVWXYZabcdefghijklmnopqrstuvwxyz.:!, -psm 6"'
for folder in os.listdir("peabody_files/Accession Files/"):
    if '.DS_Store' in folder:
        continue
    Image.open("peabody_files/Accession Files/"+folder+"/"+list(os.listdir("peabody_files/Accession Files/"+folder))[1]).show()
    site_no=input("Please enter site number: ")
    for file in os.listdir("peabody_files/Accession Files/"+folder):
        if 'DS_Store' in file:
            continue
        print(str(''.join(['-' for x in range(10)])), '\n')
        print("File", "peabody_files/Accession Files/"+folder+'/'+file)
        img = Image.open("peabody_files/Accession Files/"+folder+'/'+file)
        img = rectifyImage(img)
        xSize=img.size[0]
        ySize=img.size[1]
        catNumber = file[-12:-8]
        accNumber = file[0:file.index("_")]
        localityImg = img.crop((450, 400, xSize-450, 640))
        siteImg = img.crop((440,150, xSize-440, 250))
        nameImg = img.crop((440,5, xSize-440, 100))
        situationImg = img.crop((25,635, xSize-25, 735))

        locality = pytesseract.image_to_string(localityImg, config=configArgs)
        site = pytesseract.image_to_string(siteImg, config=configArgs)
        situation = pytesseract.image_to_string(situationImg, config=configArgs)
        name = pytesseract.image_to_string(nameImg, config=configArgs)
        print("Cat Number:", catNumber)
        print("Site Number:", site_no)
        print("Locality:", locality)
        print("Site:", site)
        print("Name:", name)
        print("Situation:", situation)
        print("ACC#:", accNumber)
        df.loc[len(df)]=[catNumber, site_no, locality, site, name, situation, accNumber, fileLocation]
# Out:
# Please enter site number: M50/1
# ----------
#
# File peabody_files/Accession Files/1/1_0001.pdf.png
# Cat Number: 0001
# Site Number: M50/1
# Locality: Locality Squibnocket Head, so
# Martha' 3 Vineyard, M
# Site: Site Squibnocket Cliff .
# Name: Name Butt of arrowhead.
# Situation: Situation on sand under shell just south of stake 1.
# ACC#: 1
# ----------
#
# File peabody_files/Accession Files/1/1_0002.pdf.png
# Cat Number: 0002
# Site Number: M50/1
# Locality: Lmnmw Squibnocket Head, so
# Martha's Vineyard, M
# Site: Site Squibnocket Cliff.
# Name: Name Butt of quartz knife.
# Situation: Situation Black sandy loam near stake 2.
# ACC#: 1
# ----------
#
# File peabody_files/Accession Files/1/1_0003.pdf.png
# Cat Number: 0003
# Site Number: M50/1
# Locality: Locality Squibnocket Head, sou
# Martha' 3 Vineyard, Ma
# Site: Site Squibnocket Cliff .
# Name: Name Crude quartz point.
# Situation: Situation Black sandy loam, 1M. east of stake A.
# ACC#: 1
# ----------
#
# File peabody_files/Accession Files/1/1_0004.pdf.png
# Cat Number: 0004
# Site Number: M50/1
# Locality: Locality Squibnooket Head, so
# Martha's Vineyard, M
# Site: Site Squibnocket Cliff.
# Name: Name Urude quartzite apea:
# Situation: Situation Top of first shell layer.
# ACC#: 1
# ----------
#
# File peabody_files/Accession Files/1/1_0005.pdf.png
# Cat Number: 0005
# Site Number: M50/1
# Locality: Locality Squibnocket Head, sou
# Martha' 3 Vineyard, Ma
# Site: Site Squibnocket Cliff .
# Name: Name Crude chopper.
# Situation: Situation Underneath lowest shell layer.
# ACC#: 1
# ----------
#
# File peabody_files/Accession Files/1/1_0006.pdf.png
# Cat Number: 0006
# Site Number: M50/1
# Locality: Locality Squibnooket Head, sou
# Martha' 8 Vineyard, Ma
# Site: Site Squibnocket Cliff.
# Name: Name Crude rectangular qua]
# Situation: Situation W. of edge of lower shell, near stake A.
# ACC#: 1
# ----------
#
# File peabody_files/Accession Files/1/1_0007.pdf.png
# Cat Number: 0007
# Site Number: M50/1
# Locality: Locality Squibnocket Head, sou
# Martha' 8 Vineyard, Ma:
# Site: Site Squibnocket Cliff .
# Name: Name Crude quartz arrowheac‘
# Situation: Situation On top of heap.
# ACC#: 1
# ----------
#
# File peabody_files/Accession Files/1/1_0008.pdf.png
# Cat Number: 0008
# Site Number: M50/1
# Locality: Locality Squibnocket Head, sou
# Martha' 8 Vineyard, Ma
# Site: Site Squibnocket Cliff .
# Name: Name Crude broken point.
# Situation: Situation Hard packed loam, W. of stake A.
# ACC#: 1
# ----------
#
# File peabody_files/Accession Files/1/1_0009.pdf.png
# Cat Number: 0009
# Site Number: M50/1
# Locality: Locality S quibnocket Head, so
# Martha' 8 Vineyard, M
# Site: Site Squibnocket Cl iff .
# Name: Name ktubbing stone.
# Situation: Situation Bottom of first shell layer.
# ACC#: 1
# ----------
#
# File peabody_files/Accession Files/1/1_0010.pdf.png
# Cat Number: 0010
# Site Number: M50/1
# Locality: Locality Squibnocket Head, sou
# Martha' 3 Vineyard, Ma
# Site: Site Squibnocket Cliff.
# Name: Name ridge of crude chipped
# Situation: Situation On top of heap.
# ACC#: 1
# ----------
#
# File peabody_files/Accession Files/1/1_0011.pdf.png
# Cat Number: 0011
# Site Number: M50/1
# Locality: Locality Squibnocket Head, sou
# Martha' 8 Vineyard, Mal
# Site: Site Squibnock et Cl iff .
# Name: Name Rounded butt of quartz
# Situation: Situation Hard black loam E. of stake 1.
# ACC#: 1
# ----------
#
# File peabody_files/Accession Files/1/1_0012.pdf.png
# Cat Number: 0012
# Site Number: M50/1
# Locality: Locality Squibnocket Head, sow
# Martha' 6 Vineyard, Mal
# Site: Site Squibnocket Cliff .
# Name: Name Point of crude arrowhe
# Situation: Situation In top layer of broken shell and loam almost upor
#
# __¢I_ _L-1‘I -I_
# ACC#: 1
# ----------
#
# File peabody_files/Accession Files/1/1_0013.pdf.png
# Cat Number: 0013
# Site Number: M50/1
# Locality: Locality Squibnocket Head, sou
# Martha' 3 Vineyard, Ma:
# Site: Site Squibnocket Cl iff .
# Name: Name Points of quartz arrow.
# Situation: Situation Black occupational dirt.
# ACC#: 1
# ----------
#
# File peabody_files/Accession Files/1/1_0014.pdf.png
# Cat Number: 0014
# Site Number: M50/1
# Locality: Locality S quibnocket Head, sou
# Martha's Vineyard, Ma
# Site: Site Squibnocket Cliff .
# Name: Name Point of large quartz
# Situation: Situation On top of heap.
# ACC#: 1
# ----------
#
# File peabody_files/Accession Files/1/1_0015.pdf.png
# Cat Number: 0015
# Site Number: M50/1
# Locality: Locality Squibnocket Head, sou
# Martha' 5 Vineyard, Ma
# Site: Site Squibnocket Cliff.
# Name: Name Quartz_ar1jow head, thj
# Situation: Situation Bottom of black loam and shell.
# ACC#: 1
# ----------
#
# File peabody_files/Accession Files/1/1_0016.pdf.png
# Cat Number: 0016
# Site Number: M50/1
# Locality: Locality Squibnocket Head, sou
# Martha' 3 Vineyard, Ma
# Site: Site
#
# Squibnocket Cliff .
# Name: Name Red quartzite k?) arrt
# Situation: Situation Bottom of black loam and shell.
# ACC#: 1
# ----------
#
# File peabody_files/Accession Files/1/1_0017.pdf.png
# Cat Number: 0017
# Site Number: M50/1
# Locality: Locality Squibnocket Head, sou
# Martha' 8 Vineyard, Ma
# Site: Site Squibnocket Cliff.
# Name: Name Crude arrow point, n01
# Situation: Situation Top of heap.
# ACC#: 1
# ----------
#
# File peabody_files/Accession Files/1/1_0018.pdf.png
# Cat Number: 0018
# Site Number: M50/1
# Locality: Locality Squibnocket Head, sou
# Martha' 3 Vineyard, Ma
# Site: Site Squibnocket Cliff.
# Name: Name Crude knife H), quar‘
# Situation: Situation Bottom of scallop shells.
# ACC#: 1
# ----------
#
# File peabody_files/Accession Files/1/1_0019.pdf.png
# Cat Number: 0019
# Site Number: M50/1
# Locality: Locality Squibnocket Head, sou
# Martha' 6 Vineyard, Ma:
#
# Q
# Site: Site Squibnooket Cliff.
# Name: Name Quartz arrow point.
# Situation: lower
# Situation In black dirt above/shell layer N.E. of p11; 3,
# ACC#: 1
# ----------
#
# File peabody_files/Accession Files/1/1_0020.pdf.png
# Cat Number: 0020
# Site Number: M50/1
# Locality: Locality Squibnocket Head, sou
# Martha' 3 Vineyard, Ma
# Site: Site Squibno cket Cl iff .
# Name: Name Butt of large crude k1
# Situation: Situation Pit 4 east of gu11Y-
# ACC#: 1
# ----------
#
# File peabody_files/Accession Files/1/1_0021.pdf.png
# Cat Number: 0021
# Site Number: M50/1
# Locality: Locality Squibnocket Head, sou
# Martha' 3 Vineyard, Ma
# Site: Site Squibnocket Cliff.
# Name: Name Broken quartz arrowhe:
# Situation: Situation First shell layer above scallops.
# ACC#: 1
# ----------
#
# File peabody_files/Accession Files/1/1_0022.pdf.png
# Cat Number: 0022
# Site Number: M50/1
# Locality: Locality S quibnocket Head, sou
# Martha' 8 Vineyard, Ma:
# Site: Site Squibnocket 01 if f .
# Name: Name Broken quartz arrowhea
# Situation: Situation Black humus between first and second shell layer:
# ACC#: 1
# ----------
#
# File peabody_files/Accession Files/1/1_0023.pdf.png
# Cat Number: 0023
# Site Number: M50/1
# Locality: Locality Squibnocket Head, sout
# Martha' 3 Vineyard Mas
# Site: Site Squibnocket Cliff.
# Name: Name Crude arrowhead.
# Situation: 35mm“ Below second shell layer in yellowish black humus
# ACC#: 1
# ----------
#
# File peabody_files/Accession Files/1/1_0024.pdf.png
# Cat Number: 0024
# Site Number: M50/1
# Locality: Locality Squibnocket Head, so
# Martha' 8 Vineyard M
# Site: Site Squibnocket Cliff .
# Name: Name Butt of arrowhead.
# Situation: Situation Below second shell layer in brown humus.
# ACC#: 1
# ----------
#
# File peabody_files/Accession Files/1/1_0025.pdf.png
# Cat Number: 0025
# Site Number: M50/1
# Locality: Locality Squibnocket Head, so
# Martha' 8 Vineyard, M
# Site: Site Squibno cket Cliff .
# Name: Name Quartz knife.
# Situation: Situation In base of first shell in W. part of heap.
# ACC#: 1
# ----------
#
# File peabody_files/Accession Files/1/1_0026.pdf.png
# Cat Number: 0026
# Site Number: M50/1
# Locality: Locality Squibnocket Head, so
# Martha‘ a vineyard, M
# Site: Site Squibnocket Cliff.
# Name: Name Quartz knife.
# Situation: Situation In humus below first shell in W. side of heap.
# ACC#: 1
# ----------
#
# File peabody_files/Accession Files/1/1_0027.pdf.png
# Cat Number: 0027
# Site Number: M50/1
# Locality: 140981“? Squibnocket Read, 30111
# Martha' a Vineyard Mat
# Site: Site Squibnocket Cliff.
# Name: Name Quartz flake arrow.
# Situation: Situation In humus below second shell in W. side of heap.
# ACC#: 1
# ----------
#
# File peabody_files/Accession Files/1/1_0028.pdf.png
# Cat Number: 0028
# Site Number: M50/1
# Locality: Locality Squibnocket Head, sou1
# Martha' 3 Vineyard, Mat
# Site: Site Squibnooket 01 if f .
# Name: N‘me Quartz arrow.
# Situation: Situation In humus near pocket of second shells.
# ACC#: 1
# ----------
#
# File peabody_files/Accession Files/1/1_0029.pdf.png
# Cat Number: 0029
# Site Number: M50/1
# Locality: Locality Squibnocket Head, so
# Martha' 3 Vineyard, M
# Site: Site Squibnocket Cliff .
# Name: Name Butt of‘large chippet
# Situation: Situation In black muddy loam west end of heap.
# ACC#: 1
# ----------
#
# File peabody_files/Accession Files/1/1_0030.pdf.png
# Cat Number: 0030
# Site Number: M50/1
# Locality: Locality Squibnocket Head, sout
# Martha.‘ 8 Vineyard, Mas
# Site: Site Squibno cket Cl iff .
# Name: Name
#
# Hoe.
# Situation: Situation Trench I at base of shells.
# ACC#: 1
# ----------
#
# File peabody_files/Accession Files/1/1_0031.pdf.png
# Cat Number: 0031
# Site Number: M50/1
# Locality: Locality Squibnocket Head, 80111
# Martha' 3 Vineyard, Mat
# Site: Site Squibnocket Cliff .
# Name: Name Unfinished slate knife
# Situation: Situation In small shell pit east of shellheaps of
# ACC#: 1
# ----------
#
# File peabody_files/Accession Files/1/1_0032.pdf.png
# Cat Number: 0032
# Site Number: M50/1
# Locality: Locality Squibnocket Head, sou
# Martha' 8 Vineyard, Ma:
# Site: Site Squibnocket Cliff .
# Name: Name Unfinished quartz lmii
# Situation: Situation In small shell pit east of shellheap of
# ACC#: 1
# ----------
#
# File peabody_files/Accession Files/1/1_0033.pdf.png
# Cat Number: 0033
# Site Number: M50/1
# Locality: Locality Bquibnocket Head, 80111
# Martha's Vineyard, Mae
# Site: Site Squibnocket Cliff.
# Name: Name Quartz arrowhead.
# Situation: Situation In very small shell pit located on bank east of
# ACC#: 1
# ----------
#
# File peabody_files/Accession Files/1/1_0034.pdf.png
# Cat Number: 0034
# Site Number: M50/1
# Locality: Locality Squibnocket Head, Bout
# Martha' 8 Vineyard, Mae
# Site: Site Squibnocket Cliff.
# Name: Name Flint arrowhead.
# Situation: Situation Top of first shell layer (west).
# ACC#: 1
# ----------
#
# File peabody_files/Accession Files/1/1_0035.pdf.png
# Cat Number: 0035
# Site Number: M50/1
# Locality: Locality Squibnocket Head, sou“
# Martha's Vineyard, Ma:
# Site: Site Squibnocket Cliff.
# Name: Name one quartz arrow.
# Situation: Situation Upper shell Tr.1.
# ACC#: 1
# ----------
#
# File peabody_files/Accession Files/1/1_0036.pdf.png
# Cat Number: 0036
# Site Number: M50/1
# Locality: Locality Squibnocket Head, sout
# Martha' 8 Vineyard, Mas
# Site: Site Squibnocket Cliff .
# Name: Name Quartz arrow.
# Situation: Situation In shell in Tr.I.
# ACC#: 1
# ----------
#
# File peabody_files/Accession Files/1/1_0037.pdf.png
# Cat Number: 0037
# Site Number: M50/1
# Locality: hxﬂﬁy Squibnocket Head, so
# Martha's Vineyard, M
# Site: Site Squibnocket Cliff.
# Name: Name Broken arrow.
# Situation: Situation In shell in Tr. I.
# ACC#: 1
# ----------
#
# File peabody_files/Accession Files/1/1_0038.pdf.png
# Cat Number: 0038
# Site Number: M50/1
# Locality: Locality Squibnocket Head, Bout
# Martha' 8 Vineyard, Mae
# Site: Site Squibnocket Cliff.
# Name: Name Crude unfinished chipp
#
# __A.l_‘A.
# Situation: Situation In shell in TI.I.
# ACC#: 1
# ----------
#
# File peabody_files/Accession Files/1/1_0039.pdf.png
# Cat Number: 0039
# Site Number: M50/1
# Locality: Locality Squibnocket Head, so
# Martha' 5 Vineyard, M
#
# -L -‘I'I
# Site: Site Squibnocket Cliff .
# Name: Name Crude notched sinker.
# Situation: Situation In small/pit located on bank east of excavation.
# ACC#: 1
# ----------
#
# File peabody_files/Accession Files/1/1_0040.pdf.png
# Cat Number: 0040
# Site Number: M50/1
# Locality: Locality Squibnocket Head, sout
# Martha) 6 Vineyard, Mas
# Site: Site Squibnocket Cliff.
# Name: Name Broken point .
# Situation: Situation Near hearteIII in humus below shells.
# ACC#: 1
# ----------
#
# File peabody_files/Accession Files/1/1_0041.pdf.png
# Cat Number: 0041
# Site Number: M50/1
# Locality: Locality Squibnocket Head, sou1
# Martha.I s Vineyard, Ma:
# Site: Site Squibnocket 01 if f .
# Name: Name Kameratone.
# Situation: Situation Found in scrap.
# ACC#: 1
# ----------
#
# File peabody_files/Accession Files/1/1_0042.pdf.png
# Cat Number: 0042
# Site Number: M50/1
# Locality: Locality Squibnocket Head, aout
# Martha' 3 Vineyard, Mae
# Site: Site Squibnooket 01 iff .
# Name: Name Deer ulna. awl.
# Situation: Situation First shell layer, N.E. of stake B.
# ACC#: 1
# ----------
#
# File peabody_files/Accession Files/1/1_0043.pdf.png
# Cat Number: 0043
# Site Number: M50/1
# Locality: Locality Squibnocket Head, 50111
# Martha's Vineyard, Ma:
# Site: Site Squibnocket Cliff.
# Name: Name Point of broken awl.
# Situation: Situation In hard packed loam.
# ACC#: 1
# ----------
#
# File peabody_files/Accession Files/1/1_0044.pdf.png
# Cat Number: 0044
# Site Number: M50/1
# Locality: Locality Squibnocket Head, sou1
# Martha' 3 Vineyard, Mas
# Site: Site Squibnocket Cliff .
# Name: Name Bone awl.
# Situation: Situation Beneath shell in black sandy loam, near stake A
# ACC#: 1
# ----------
#
# File peabody_files/Accession Files/1/1_0045.pdf.png
# Cat Number: 0045
# Site Number: M50/1
# Locality: Lawmw Squibnocket Head, sout
# Martha' 8 Vineyard, Mas
# Site: Site Squibnocket Cliff.
# Name: Name Very small. bone awl, o
# Situation: Situation Lower scallop shell, near stake B.
# ACC#: 1
# ----------
#
# File peabody_files/Accession Files/1/1_0046.pdf.png
# Cat Number: 0046
# Site Number: M50/1
# Locality: Locality Squibnocket Head, eout
# Martha' 8 Vineyard, Mae
# Site: Site Squibnocket 01 if f .
# Name: Name Piece of worked bone.
# Situation: Situation Shells of lower layer.
# ACC#: 1
# ----------
#
# File peabody_files/Accession Files/1/1_0047.pdf.png
# Cat Number: 0047
# Site Number: M50/1
# Locality: Locality Squibnocket Head, sou
# Martha' 3 Vineyard, Ma:
# Site: Site Squibnocket Cliff.
# Name: N'me Broken awl .
# Situation: Situation First shell layer.
# ACC#: 1
# ----------
#
# File peabody_files/Accession Files/1/1_0048.pdf.png
# Cat Number: 0048
# Site Number: M50/1
# Locality: Locality Squibnocket Head, sou
# Martha' 9 Vineyard, Ma
# Site: Site Squibno cket Clif f .
# Name: Name Bone awl .
# Situation: Situation Near too of upper shells.
# ACC#: 1
# ----------
#
# File peabody_files/Accession Files/1/1_0049.pdf.png
# Cat Number: 0049
# Site Number: M50/1
# Locality: Locality Squibnocket Head, 90‘
# Martha's Vineyard, M
# Site: Site Squibnocket Cliff.
# Name: Name Middle of bone ail.
# Situation: Situation First shell layer, W. end.
# ACC#: 1
# ----------
#
# File peabody_files/Accession Files/1/1_0050.pdf.png
# Cat Number: 0050
# Site Number: M50/1
# Locality: Locality Squibnocket Head, so
# Martha' 8 Vineyard, M
# Site: Site Squibnocket Cliff .
# Name: Name Piece of bone awl.
# Situation: Situation First shell layer.
# ACC#: 1
# ----------
#
# File peabody_files/Accession Files/1/1_0051.pdf.png
# Cat Number: 0051
# Site Number: M50/1
# Locality: Locality Squibnocket Head, sou
# Martha' 6 Vineyard, Ma
# Site: Site Squibno cke 1: Cl iff .
# Name: Name Bone awl.
# Situation: Situation Black occupational debris over west end of pit 1
# ACC#: 1
# ----------
#
# File peabody_files/Accession Files/1/1_0052.pdf.png
# Cat Number: 0052
# Site Number: M50/1
# Locality: Locality Squibnooket Head, sou1
# Martha' 3 Vineyard, Mal
# Site: Site Squibnocket Cl iff .
# Name: Name Small bone point.
# Situation: Situation In scallop shells.
# ACC#: 1
# ----------
#
# File peabody_files/Accession Files/1/1_0053.pdf.png
# Cat Number: 0053
# Site Number: M50/1
# Locality: Locality Squibnocket Head, sou
# Martha' 3 Vineyard, Ma:
# Site: Site Squibnocket Cliff.
# Name: Name Blue wampum bead.
# Situation: Situation Top of heap near west end of cut.
# ACC#: 1
# ----------
#
# File peabody_files/Accession Files/1/1_0054.pdf.png
# Cat Number: 0054
# Site Number: M50/1
# Locality: locality Squibnocket Head, sou
# Martha} 8 Vineyard, Ma:
# Site: Site Squibnocket 01 iff.
# Name: Name Antler tine awl.
# Situation: Situation In black dirt above lower shell layer west of
#
# __4IA. n
# ACC#: 1
# ----------
#
# File peabody_files/Accession Files/1/1_0055.pdf.png
# Cat Number: 0055
# Site Number: M50/1
# Locality: Locality Squibnocket Head, so
# Martha' 3 Vineyard, M
# Site: Site Squibnocket Cliff.
# Name: Name Antler socket.
# Situation: Situation In shells at base of first layer at west end.
# ACC#: 1
# ----------
#
# File peabody_files/Accession Files/1/1_0056.pdf.png
# Cat Number: 0056
# Site Number: M50/1
# Locality: Locality Squibnocket Head, sou1
# Martha's Vineyard, Ma:
# Site: Site Squibno cket 01 if f .
# Name: Name Broken all.
# Situation: Situation In base of first shell in W. part of heap.
# ACC#: 1
# ----------
#
# File peabody_files/Accession Files/1/1_0057.pdf.png
# Cat Number: 0057
# Site Number: M50/1
# Locality: Locality Squibnocket Head, sou
# Martha' 5 Vineyard, Mal
# Site: Site Squibnocket 01 iff.
# Name: Name Broken awl .
# Situation: Situation In base of first shell in W. part of heap.
# ACC#: 1
# ----------
#
# File peabody_files/Accession Files/1/1_0058.pdf.png
# Cat Number: 0058
# Site Number: M50/1
# Locality: Locality Squibnocket Head, sou‘
# Martha’s Vineyayd, Ma:
# Site: Site Squibnocket Cliff.
# Name: Name 'Awl with point and has
# Situation: Situation In base of first shell in W. part of heap.
# ACC#: 1
# ----------
#
# File peabody_files/Accession Files/1/1_0059.pdf.png
# Cat Number: 0059
# Site Number: M50/1
# Locality: Locality Squibnocket Head, 50111
# Martha' 9 Vineyard, Ma:
# Site: Site Squibnocket 01 iff.
# Name: Name Bone bead.
# Situation: Situation Between first and second. shell layers in black
# ACC#: 1
# ----------
#
# File peabody_files/Accession Files/1/1_0060.pdf.png
# Cat Number: 0060
# Site Number: M50/1
# Locality: Locality Squibnocket Head, so
# Martha's Vineyard, M
# Site: Site Squibnocket Cliff.
# Name: Name I’ierced fish vertabra
# Situation: Situation Found in looking over scrap.
# ACC#: 1
# ----------
#
# File peabody_files/Accession Files/1/1_0061.pdf.png
# Cat Number: 0061
# Site Number: M50/1
# Locality: Locality Squibnocket Head, 30111
# Martha) 5 Vineyard, Mat
# Site: Site Squibnocket 01 if f .
# Name: Name Piece of bone awl.
# Situation: Situation Found in scrap.
# ACC#: 1
# ----------
#
# File peabody_files/Accession Files/1/1_0062.pdf.png
# Cat Number: 0062
# Site Number: M50/1
# Locality: Locality S quibnocket Head, sou
# Martha' 3 Vineyard, Ma:
# Site: Site Squibnocket 01 iii .
# Name: Name Out antler.
# Situation: Situation Found in scrap.
# ACC#: 1
# ----------
#
# File peabody_files/Accession Files/1/1_0063.pdf.png
# Cat Number: 0063
# Site Number: M50/1
# Locality: Locality S quibnocket Head, sou1
# Martha' 8 Vineyard, Ma:
# Site: Site Squibnocket Cliff.
# Name: Name Scraps 01’ crude potter
# Situation: Situation Top of first shell layer.
# ACC#: 1
# ----------
#
# File peabody_files/Accession Files/1/1_0064.pdf.png
# Cat Number: 0064
# Site Number: M50/1
# Locality: Locality Squibnocket Head, 80111
# Martha' 3 Vineyard, Ma:
# Site: Site Squibnocket Cliff.
# Name: Name Two pieces of undeoora
# Situation: Situation Bottom of black loam and shell.
# ACC#: 1
# ----------
#
# File peabody_files/Accession Files/1/1_0065.pdf.png
# Cat Number: 0065
# Site Number: M50/1
# Locality: Locality Squibnocket Head, sou
# Martha' 6 Vineyard, Ma:
# Site: Site Squibnocket 01 if f .
# Name: Name Piece of pottery.
# Situation: Situation First shell layer above sca110ps.
# ACC#: 1
# ----------
#
# File peabody_files/Accession Files/1/1_0066.pdf.png
# Cat Number: 0066
# Site Number: M50/1
# Locality: Locality Squibnocket Head, aou‘
# Martha's Vineyard, Mal
# Site: Site Squibnocket 01 iff .
# Name: Name Small pieom
# Situation: Situation Found in looking over scrap.
# ACC#: 1
# Please enter site number:
# ----------
#
# File peabody_files/Accession Files/10/18_1548.pdf.png
# Cat Number: 1548
# Site Number:
# Locality: Wt? From camp at "Tom 1111]
# near Mono Lake, Ga11f<
# Site: . pinon pine, handles ho
# 5‘“ over cord.
# Name: Name ”8:156:54” for 0333.9 at?
# Situation: Situation
# ACC#: 18
# ----------
#
# File peabody_files/Accession Files/10/18_1549.pdf.png
# Cat Number: 1549
# Site Number:
# Locality: Locality From camp near l'Willie
# Mono Lake.
# Site: horsehair handles .
# Site Mono Indians .
# Name: Name "8.156! pottle £013-08???
# Situation: Situation
# ACC#: 18
# ----------
#
# File peabody_files/Accession Files/10/18_1550.pdf.png
# Cat Number: 1550
# Site Number:
# Locality: Locality Mary's Camp, Yosemite,
# Site: Site Miwok .
# Name: Name Einnowing plate.
#
# A-._L1.l__._ L___‘ _A--l1
# Situation: Situation
# ACC#: 18
# ----------
#
# File peabody_files/Accession Files/10/18_1551.pdf.png
# Cat Number: 1551
# Site Number:
# Locality: Locality Lucy's camp, Yosemite,
# Site: Site Miwok.
# Name: Name [inhaling plate.
#
# , _,-.II.
# Situation: Situation
# ACC#: 18
# ----------
#
# File peabody_files/Accession Files/10/18_1552.pdf.png
# Cat Number: 1552
# Site Number:
# Locality: Locality Soda Spring camp near
# Plumas Oo. , California
# Site: \U'CUHULLIAF. luay, puaa&u
#
# Site Maidu.
# Name: Name l1n1_10_w1ng_ palate. Typi
# Situation: Situation
# ACC#: 18
# ----------
#
# File peabody_files/Accession Files/10/18_1553.pdf.png
# Cat Number: 1553
# Site Number:
# Locality: ! Locality Madera or Mariposa cou
# Site: manposa counues o: 08.1..
# Site from root of tall "brake‘I
# Name: Name Basket made of the zoo
#
# .__.__‘ 3A--..) 1.. 4.1.- .a-_.LL,I-|-I
# Situation: Situation
# ACC#: 18
# ----------
#
# File peabody_files/Accession Files/10/18_1554.pdf.png
# Cat Number: 1554
# Site Number:
# Locality: Locality Camp at "Pioneer" 1:: A
# California.
# Site: Site Maidu.
# Name: Name Cooking basket .
# Situation: Situation
# ACC#: 18
# ----------
#
# File peabody_files/Accession Files/10/18_1555.pdf.png
# Cat Number: 1555
# Site Number:
# Locality: Locality 'Blind Dicks Camp" net
# Yosemite Falls in Val]
# Site: Site Miwok .
# Name: Name Cooking pgsket, In us
# Situation: Situation
# ACC#: 18
# ----------
#
# File peabody_files/Accession Files/10/18_1556.pdf.png
# Cat Number: 1556
# Site Number:
# Locality: Locality California.
# Site: Site
# Name: Name Food_‘9§.sket. “Iona Ix;
# Situation: Situation
# ACC#: 18
# ----------
#
# File peabody_files/Accession Files/10/18_1557.pdf.png
# Cat Number: 1557
# Site Number:
# Locality: Locality "Capt. Alleck's camp",
# Valley, California.
# Site: Site
#
# Maidu.
# Name: Name Cooking basket. Has b
#
# I—qA,
# Situation: Situation
# ACC#: 18
# ----------
#
# File peabody_files/Accession Files/10/18_1558.pdf.png
# Cat Number: 1558
# Site Number:
# Locality: | Locality American Valley, 08.111
# Site: Site Ma idu .
# Name: Name 090k1ng paaket. Of w}
#
# 1——
# Situation: Situation
# ACC#: 18
# ----------
#
# File peabody_files/Accession Files/10/18_1559.pdf.png
# Cat Number: 1559
# Site Number:
# Locality: I Locality California.
# Site: Site
#
# Maidu.
# Name: Name Burden basket. (Plume.
# Situation: Situation
# ACC#: 18
# ----------
#
# File peabody_files/Accession Files/10/18_1560.pdf.png
# Cat Number: 1560
# Site Number:
# Locality: Locality Camp at “Williams Ram
# Lake, California.
# Site: ( mono lndl an)
# Site
# Name: Name Burden baskej; of w}1]_._c_:
# Situation: Situation
# ACC#: 18
# ----------
#
# File peabody_files/Accession Files/10/18_1561.pdf.png
# Cat Number: 1561
# Site Number:
# Locality: Locality "Bob's camp", (America
# Plumas Go. , Oaliforni:
# Site: of Willow and pine 1‘00
# Site Kaidu.
# Name: Name Burden_ basket. Gnawed
# Situation: Situation
# ACC#: 18
# ----------
#
# File peabody_files/Accession Files/10/18_1562.pdf.png
# Cat Number: 1562
# Site Number:
# Locality: Locality Indian Valley, lenae
# nia.
# Site: Site
#
# Maidu .
# Name: Name Burden basket.
# Situation: Situation
# ACC#: 18
# ----------
#
# File peabody_files/Accession Files/10/18_1563.pdf.png
# Cat Number: 1563
# Site Number:
# Locality: Locality “Bob's Camp" (America:
# Plumas Co. , Californiz
# Site: weave .
# Site Maidu ?
# Name: Name Burden basket. willow
#
# 71“.. _--.L- M_#J__1 I!
# Situation: Situation
# ACC#: 18
# ----------
#
# File peabody_files/Accession Files/10/18_1564.pdf.png
# Cat Number: 1564
# Site Number:
# Locality: Locality American Valley, Plum:
# Site: almanac. wormananlp .
# Site Maidu .
# Name: Name Basket made by nary Ha
#
# —————— 27-1 ‘ A.- H1--_-
# Situation: Situation
# ACC#: 18
# ----------
#
# File peabody_files/Accession Files/10/18_1565.pdf.png
# Cat Number: 1565
# Site Number:
# Locality: Locality California.
# Site: Site Miwok .
# Name: Name Basket made by a. chi
# Situation: Situation
# ACC#: 18
# ----------
#
# File peabody_files/Accession Files/10/18_1566.pdf.png
# Cat Number: 1566
# Site Number:
# Locality: Locality California.
# Site: . ulono Indian)
# Sxte
# Name: Name Cooking basket of will
#
# _-LJ.-.._ “_‘_-L- ______
# Situation: Situation
# ACC#: 18
# ----------
#
# File peabody_files/Accession Files/10/18_1567.pdf.png
# Cat Number: 1567
# Site Number:
# Locality: “unity California.
# Site: _ Sierras. (Madera Co.
# 5“" Yokuts ?
# Name: Name Basket _made_ 91’ the IOC
# Situation: Situation
# ACC#: 18
# ----------
#
# File peabody_files/Accession Files/10/18_1568.pdf.png
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-22-649c82fcd6a3> in <module>()
#      13         print("File", "peabody_files/Accession Files/"+folder+'/'+file)
#      14         img = Image.open("peabody_files/Accession Files/"+folder+'/'+file)
# ---> 15         img = rectifyImage(img)
#      16         xSize=img.size[0]
#      17         ySize=img.size[1]
#
# <ipython-input-20-7bf9a0aae6cb> in rectifyImage(image)
#      90     bw = gray.point(lambda x: 0 if x<200 else 255, '1')
#      91     # Rotate image
# ---> 92     b, m = bestLine(bw, 500, 700, -.05, .05)
#      93     deg = math.degrees(math.sin(abs(m*xSize)/xSize))
#      94     bw = bw.rotate(-deg, expand=True)
#
# <ipython-input-20-7bf9a0aae6cb> in bestLine(image, bMin, bMax, mMin, mMax, mStep)
#      13                 if y > image.size[1] or x > image.size[0] or y < 1 or x < 1:
#      14                     continue
# ---> 15                 if image.getpixel((x, y)) == 0:
#      16                     score += momentum
#      17                     momentum += 1
#
# /Users/localhost/.pyenv/versions/anaconda3-4.1.0/lib/python3.5/site-packages/PIL/Image.py in getpixel(self, xy)
#    1208         """
#    1209
# -> 1210         self.load()
#    1211         if self.pyaccess:
#    1212             return self.pyaccess.getpixel(xy)
#
# /Users/localhost/.pyenv/versions/anaconda3-4.1.0/lib/python3.5/site-packages/PIL/Image.py in load(self)
#     782                 if self.pyaccess:
#     783                     return self.pyaccess
# --> 784             return self.im.pixel_access(self.readonly)
#     785
#     786     def verify(self):
#
# KeyboardInterrupt:

# %%
df.to_csv("test.csv")
